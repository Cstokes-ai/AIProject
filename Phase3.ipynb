# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import keras

# %%
#first have to reload my data
dataset = pd.read_csv('loan_data.csv')
shuffle_dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)
from keras.models import Sequential
print(shuffle_dataset)
# Out:
#        person_age person_gender person_education  person_income  \
# 0            32.0          male        Associate        96865.0
# 1            24.0          male        Associate        56838.0
# 2            22.0        female           Master        37298.0
# 3            23.0        female         Bachelor        39944.0
# 4            42.0          male      High School        67974.0
# ...           ...           ...              ...            ...
# 44995        26.0          male      High School        88451.0
# 44996        25.0        female      High School        34772.0
# 44997        33.0        female        Associate        58317.0
# 44998        26.0          male           Master       178602.0
# 44999        26.0        female      High School       210894.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                  10              MORTGAGE     7500.0          EDUCATION
# 1                   6                  RENT     9000.0          EDUCATION
# 2                   0                  RENT     5000.0            MEDICAL
# 3                   1                   OWN     5000.0            VENTURE
# 4                  20              MORTGAGE    10000.0    HOMEIMPROVEMENT
# ...               ...                   ...        ...                ...
# 44995               6              MORTGAGE    10625.0          EDUCATION
# 44996               3              MORTGAGE     5876.0    HOMEIMPROVEMENT
# 44997               9              MORTGAGE    10707.0            VENTURE
# 44998               6                  RENT    20000.0  DEBTCONSOLIDATION
# 44999               4              MORTGAGE    15000.0           PERSONAL
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0               6.04                 0.08                        10.0
# 1              11.49                 0.16                         4.0
# 2              14.88                 0.13                         4.0
# 3              13.99                 0.13                         3.0
# 4              15.41                 0.15                        11.0
# ...              ...                  ...                         ...
# 44995           6.03                 0.12                         4.0
# 44996          11.69                 0.17                         4.0
# 44997          10.74                 0.18                         9.0
# 44998          17.99                 0.11                         3.0
# 44999          11.01                 0.07                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               601                             No            0
# 1               647                            Yes            0
# 2               711                             No            1
# 3               597                            Yes            0
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           559                            Yes            0
# 44996           647                             No            1
# 44997           652                            Yes            0
# 44998           604                             No            1
# 44999           664                            Yes            0
#
# [45000 rows x 14 columns]

# %%
#also, i want to determine if my data is evenly split

loan_status_counts = shuffle_dataset['loan_status'].value_counts()
print(loan_status_counts)
# Out:
# loan_status
# 0    35000
# 1    10000
# Name: count, dtype: int64

# %%
# Reload the dataset
dataset = pd.read_csv('loan_data.csv')

# Identify categorical columns
categorical_columns = dataset.select_dtypes(include=['object']).columns

# Apply one-hot encoding to categorical columns
dataset = pd.get_dummies(dataset, columns=categorical_columns, drop_first=True)

# Shuffle the dataset
shuffle_dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Split the data into training and test sets
train_set = shuffle_dataset[:int(len(shuffle_dataset) * 0.8)]
test_set = shuffle_dataset[int(len(shuffle_dataset) * 0.8):]

# Normalize the numeric features
normalize_data = StandardScaler()
train_features = normalize_data.fit_transform(train_set.drop('loan_status', axis=1))
test_features = normalize_data.transform(test_set.drop('loan_status', axis=1))

# Extract labels
train_labels = train_set['loan_status']
test_labels = test_set['loan_status']

# Create a simple logistic regression model using TensorFlow/Keras as the baseline
model = Sequential()
model.add(tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(train_features.shape[1],)))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model on the training set and evaluate its accuracy on the validation set
model.fit(train_features, train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
model.evaluate(test_features, test_labels)

# Make predictions on the test set
predictions = (model.predict(test_features) > 0.5).astype("int32")

# Calculate precision, recall, and F1 score
precision = precision_score(test_labels, predictions)
recall = recall_score(test_labels, predictions)
f1 = f1_score(test_labels, predictions)

# Print the evaluation metrics
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Save the best model using model checkpointing
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.h5',
    monitor='val_accuracy',
    save_best_only=True
)

# Retrain the model with checkpointing
model.fit(
    train_features,
    train_labels,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[checkpoint_callback]
)

# Plot learning curves
history = model.history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# c:\Users\corne\Downloads\AIProject\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7381 - loss: 0.5423 - val_accuracy: 0.8624 - val_loss: 0.3642
# Epoch 2/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8680 - loss: 0.3471 - val_accuracy: 0.8871 - val_loss: 0.2904
# Epoch 3/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8868 - loss: 0.2854 - val_accuracy: 0.8963 - val_loss: 0.2600
# Epoch 4/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8923 - loss: 0.2603 - val_accuracy: 0.8964 - val_loss: 0.2454
# Epoch 5/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8952 - loss: 0.2455 - val_accuracy: 0.8978 - val_loss: 0.2374
# Epoch 6/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8957 - loss: 0.2370 - val_accuracy: 0.8978 - val_loss: 0.2327
# Epoch 7/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8954 - loss: 0.2319 - val_accuracy: 0.8985 - val_loss: 0.2298
# Epoch 8/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8969 - loss: 0.2304 - val_accuracy: 0.8978 - val_loss: 0.2279
# Epoch 9/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8931 - loss: 0.2325 - val_accuracy: 0.8981 - val_loss: 0.2263
# Epoch 10/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8927 - loss: 0.2342 - val_accuracy: 0.8982 - val_loss: 0.2254
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8988 - loss: 0.2221
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Precision: 0.7809722948248824
# Recall: 0.7503766951280764
# F1 Score: 0.7653688524590164
# Epoch 1/10
# 897/900 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.2220
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8999 - loss: 0.2221 - val_accuracy: 0.8982 - val_loss: 0.2247
# Epoch 2/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8934 - loss: 0.2277 - val_accuracy: 0.8982 - val_loss: 0.2240
# Epoch 3/10
# 891/900 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8962 - loss: 0.2285
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8962 - loss: 0.2285 - val_accuracy: 0.8993 - val_loss: 0.2237
# Epoch 4/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8926 - loss: 0.2306 - val_accuracy: 0.8978 - val_loss: 0.2235
# Epoch 5/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8967 - loss: 0.2249 - val_accuracy: 0.8983 - val_loss: 0.2231
# Epoch 6/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8934 - loss: 0.2284 - val_accuracy: 0.8983 - val_loss: 0.2228
# Epoch 7/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8936 - loss: 0.2299 - val_accuracy: 0.8992 - val_loss: 0.2226
# Epoch 8/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8953 - loss: 0.2273 - val_accuracy: 0.8983 - val_loss: 0.2223
# Epoch 9/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8934 - loss: 0.2291 - val_accuracy: 0.8982 - val_loss: 0.2223
# Epoch 10/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8964 - loss: 0.2226 - val_accuracy: 0.8975 - val_loss: 0.2222

# %%
# Reload the dataset
dataset = pd.read_csv('loan_data.csv')

# Identify categorical columns
categorical_columns = dataset.select_dtypes(include=['object']).columns

# Apply one-hot encoding to categorical columns
dataset = pd.get_dummies(dataset, columns=categorical_columns, drop_first=True)

# Shuffle the dataset
shuffle_dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Split the data into training and test sets
train_set = shuffle_dataset[:int(len(shuffle_dataset) * 0.8)]
test_set = shuffle_dataset[int(len(shuffle_dataset) * 0.8):]

# Normalize the numeric features
normalize_data = StandardScaler()
train_features = normalize_data.fit_transform(train_set.drop('loan_status', axis=1))
test_features = normalize_data.transform(test_set.drop('loan_status', axis=1))

# Extract labels
train_labels = train_set['loan_status']
test_labels = test_set['loan_status']

# Create a simple logistic regression model using TensorFlow/Keras as the baseline
model = Sequential()
model.add(tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(train_features.shape[1],)))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model on the training set and evaluate its accuracy on the validation set
history = model.fit(train_features, train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_features, test_labels)

# Make predictions on the test set
predictions = (model.predict(test_features) > 0.5).astype("int32")

# Calculate precision, recall, and F1 score
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(test_labels, predictions)
recall = recall_score(test_labels, predictions)
f1 = f1_score(test_labels, predictions)

# Print the evaluation metrics
print(f"Test Accuracy: {test_accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")

# Save the best model using model checkpointing
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.h5',
    monitor='val_accuracy',
    save_best_only=True
)

# Retrain the model with checkpointing
model.fit(
    train_features,
    train_labels,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[checkpoint_callback]
)

# Plot learning curves
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Create a table summarizing the results
results_table = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1 Score"],
    "Score": [test_accuracy, precision, recall, f1]
})

# Display the table
print("\nResults Summary:")
print(results_table)
# Out:
# Epoch 1/10
# c:\Users\corne\Downloads\AIProject\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5598 - loss: 0.7409 - val_accuracy: 0.8649 - val_loss: 0.4096
# Epoch 2/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8773 - loss: 0.3738 - val_accuracy: 0.8928 - val_loss: 0.3083
# Epoch 3/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8908 - loss: 0.2985 - val_accuracy: 0.8957 - val_loss: 0.2699
# Epoch 4/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8940 - loss: 0.2648 - val_accuracy: 0.8981 - val_loss: 0.2509
# Epoch 5/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8933 - loss: 0.2514 - val_accuracy: 0.8963 - val_loss: 0.2407
# Epoch 6/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8927 - loss: 0.2438 - val_accuracy: 0.8965 - val_loss: 0.2348
# Epoch 7/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8975 - loss: 0.2330 - val_accuracy: 0.8981 - val_loss: 0.2311
# Epoch 8/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8930 - loss: 0.2372 - val_accuracy: 0.8978 - val_loss: 0.2286
# Epoch 9/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8951 - loss: 0.2346 - val_accuracy: 0.8974 - val_loss: 0.2273
# Epoch 10/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8964 - loss: 0.2280 - val_accuracy: 0.8978 - val_loss: 0.2262
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8981 - loss: 0.2221
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Test Accuracy: 0.897777795791626
# Precision: 0.7805133577789418
# Recall: 0.7483676544450025
# F1 Score: 0.764102564102564
# Epoch 1/10
# 891/900 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.2292
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8946 - loss: 0.2292 - val_accuracy: 0.8979 - val_loss: 0.2250
# Epoch 2/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8961 - loss: 0.2285
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8960 - loss: 0.2285 - val_accuracy: 0.8981 - val_loss: 0.2245
# Epoch 3/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8983 - loss: 0.2232 - val_accuracy: 0.8968 - val_loss: 0.2243
# Epoch 4/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8923 - loss: 0.2308 - val_accuracy: 0.8979 - val_loss: 0.2236
# Epoch 5/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8962 - loss: 0.2243 - val_accuracy: 0.8978 - val_loss: 0.2233
# Epoch 6/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8928 - loss: 0.2334 - val_accuracy: 0.8976 - val_loss: 0.2231
# Epoch 7/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8961 - loss: 0.2245 - val_accuracy: 0.8972 - val_loss: 0.2230
# Epoch 8/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8949 - loss: 0.2265 - val_accuracy: 0.8971 - val_loss: 0.2226
# Epoch 9/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8953 - loss: 0.2230 - val_accuracy: 0.8981 - val_loss: 0.2226
# Epoch 10/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8963 - loss: 0.2236 - val_accuracy: 0.8975 - val_loss: 0.2223
# Results Summary:
#       Metric     Score
# 0   Accuracy  0.897778
# 1  Precision  0.780513
# 2     Recall  0.748368
# 3   F1 Score  0.764103

# %%
# Reload the dataset
dataset = pd.read_csv('loan_data.csv')

# Identify categorical columns
categorical_columns = dataset.select_dtypes(include=['object']).columns

# Apply one-hot encoding to categorical columns
dataset = pd.get_dummies(dataset, columns=categorical_columns, drop_first=True)

# Shuffle the dataset
shuffle_dataset = dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Split the data into training and test sets
train_set = shuffle_dataset[:int(len(shuffle_dataset) * 0.8)]
test_set = shuffle_dataset[int(len(shuffle_dataset) * 0.8):]

# Normalize the numeric features
normalize_data = StandardScaler()
train_features = normalize_data.fit_transform(train_set.drop('loan_status', axis=1))
test_features = normalize_data.transform(test_set.drop('loan_status', axis=1))

# Extract labels
train_labels = train_set['loan_status']
test_labels = test_set['loan_status']

# Logistic Regression Model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

logistic_model = LogisticRegression()
logistic_model.fit(train_features, train_labels)

# Evaluate Logistic Regression on the test set
logistic_predictions = logistic_model.predict(test_features)

# Calculate metrics for Logistic Regression
logistic_precision = precision_score(test_labels, logistic_predictions)
logistic_recall = recall_score(test_labels, logistic_predictions)
logistic_f1 = f1_score(test_labels, logistic_predictions)
logistic_accuracy = accuracy_score(test_labels, logistic_predictions)

# Neural Network Model
model = Sequential()
model.add(tf.keras.layers.Dense(1, activation='sigmoid', input_shape=(train_features.shape[1],)))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the Neural Network model
history = model.fit(train_features, train_labels, epochs=10, batch_size=32, validation_split=0.2)

# Evaluate the Neural Network model on the test set
test_loss, test_accuracy = model.evaluate(test_features, test_labels)

# Make predictions with the Neural Network model
nn_predictions = (model.predict(test_features) > 0.5).astype("int32")

# Calculate metrics for Neural Network
nn_precision = precision_score(test_labels, nn_predictions)
nn_recall = recall_score(test_labels, nn_predictions)
nn_f1 = f1_score(test_labels, nn_predictions)

# Create a table for Logistic Regression Model evaluation
lr_results_table = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1-score"],
    "Test": [f"{logistic_accuracy * 100:.2f} %", 
             f"{logistic_precision * 100:.2f} %", 
             f"{logistic_recall * 100:.2f} %", 
             f"{logistic_f1:.4f}"]
})

# Display the Logistic Regression results table
print("\nTable 7: Logistic Regression Model evaluation using precision, recall, and F1 score")
print(lr_results_table)

# Create a table for Neural Network Model evaluation
nn_results_table = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1-score"],
    "Test": [f"{test_accuracy * 100:.2f} %", 
             f"{nn_precision * 100:.2f} %", 
             f"{nn_recall * 100:.2f} %", 
             f"{nn_f1:.4f}"]
})

# Display the Neural Network results table
print("\nTable 6: Neural Network Model evaluation using precision, recall, and F1 score")
print(nn_results_table)

# Plot learning curves for Neural Network
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Learning Curves for Neural Network')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# c:\Users\corne\Downloads\AIProject\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5975 - loss: 0.7070 - val_accuracy: 0.8413 - val_loss: 0.3933
# Epoch 2/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8546 - loss: 0.3660 - val_accuracy: 0.8804 - val_loss: 0.3038
# Epoch 3/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8847 - loss: 0.2954 - val_accuracy: 0.8907 - val_loss: 0.2678
# Epoch 4/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8894 - loss: 0.2673 - val_accuracy: 0.8957 - val_loss: 0.2503
# Epoch 5/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8940 - loss: 0.2497 - val_accuracy: 0.8963 - val_loss: 0.2407
# Epoch 6/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8975 - loss: 0.2405 - val_accuracy: 0.8960 - val_loss: 0.2351
# Epoch 7/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8970 - loss: 0.2339 - val_accuracy: 0.8972 - val_loss: 0.2313
# Epoch 8/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8950 - loss: 0.2369 - val_accuracy: 0.8974 - val_loss: 0.2292
# Epoch 9/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8939 - loss: 0.2306 - val_accuracy: 0.8972 - val_loss: 0.2275
# Epoch 10/10
# 900/900 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8964 - loss: 0.2270 - val_accuracy: 0.8971 - val_loss: 0.2262
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8980 - loss: 0.2223
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Table 7: Logistic Regression Model evaluation using precision, recall, and F1 score
#       Metric     Test
# 0   Accuracy  89.83 %
# 1  Precision  78.26 %
# 2     Recall  74.84 %
# 3   F1-score   0.7651
#
# Table 6: Neural Network Model evaluation using precision, recall, and F1 score
#       Metric     Test
# 0   Accuracy  89.77 %
# 1  Precision  77.92 %
# 2     Recall  74.99 %
# 3   F1-score   0.7643
